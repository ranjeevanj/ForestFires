# %%
import pandas as pd

# %%
pip install pandas
# Out:
# Requirement already satisfied: pandas in c:\users\jranj\anaconda3\lib\site-packages (2.2.2)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\jranj\anaconda3\lib\site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\jranj\anaconda3\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\jranj\anaconda3\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\jranj\anaconda3\lib\site-packages (from pandas) (2023.3)
# Requirement already satisfied: six>=1.5 in c:\users\jranj\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np

# %%
pip install scikit-learn
# Out:
# Requirement already satisfied: scikit-learn in c:\users\jranj\anaconda3\lib\site-packages (1.4.2)
# Requirement already satisfied: numpy>=1.19.5 in c:\users\jranj\anaconda3\lib\site-packages (from scikit-learn) (1.26.4)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\jranj\anaconda3\lib\site-packages (from scikit-learn) (1.13.1)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\jranj\anaconda3\lib\site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\jranj\anaconda3\lib\site-packages (from scikit-learn) (2.2.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install ucimlrepo
# Out:
# Collecting ucimlrepo
#   Downloading ucimlrepo-0.0.7-py3-none-any.whl.metadata (5.5 kB)
# Requirement already satisfied: pandas>=1.0.0 in c:\users\jranj\anaconda3\lib\site-packages (from ucimlrepo) (2.2.2)
# Requirement already satisfied: certifi>=2020.12.5 in c:\users\jranj\anaconda3\lib\site-packages (from ucimlrepo) (2024.8.30)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\jranj\anaconda3\lib\site-packages (from pandas>=1.0.0->ucimlrepo) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\jranj\anaconda3\lib\site-packages (from pandas>=1.0.0->ucimlrepo) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\jranj\anaconda3\lib\site-packages (from pandas>=1.0.0->ucimlrepo) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\jranj\anaconda3\lib\site-packages (from pandas>=1.0.0->ucimlrepo) (2023.3)
# Requirement already satisfied: six>=1.5 in c:\users\jranj\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas>=1.0.0->ucimlrepo) (1.16.0)
# Downloading ucimlrepo-0.0.7-py3-none-any.whl (8.0 kB)
# Installing collected packages: ucimlrepo
# Successfully installed ucimlrepo-0.0.7
# Note: you may need to restart the kernel to use updated packages.

# %%
from ucimlrepo import fetch_ucirepo

# %%
forest_fires = fetch_ucirepo(id=162)

# %%
X = forest_fires.data.features 
y = forest_fires.data.targets

# %%
df = pd.concat([X, y], axis=1)

# %%
df.head()
# Out:
#    X  Y  month  day  FFMC   DMC     DC  ISI  temp  RH  wind  rain  area
# 0  7  5      7    0  86.2  26.2   94.3  5.1   8.2  51   6.7   0.0   0.0
# 1  7  4     10    5  90.6  35.4  669.1  6.7  18.0  33   0.9   0.0   0.0
# 2  7  4     10    2  90.6  43.7  686.9  6.7  14.6  33   1.3   0.0   0.0
# 3  8  6      7    0  91.7  33.3   77.5  9.0   8.3  97   4.0   0.2   0.0
# 4  8  6      7    3  89.3  51.3  102.2  9.6  11.4  99   1.8   0.0   0.0

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from sklearn.model_selection import train_test_split

# %%
from sklearn.linear_model import LinearRegression

# %%
from sklearn.preprocessing import StandardScaler

# %%
import seaborn as sns

# %%
model = LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
def gradient_descent(X, y, learning_rate=0.01, num_iterations=1000):
    m, n = X.shape
    theta = np.zeros(n)
    errors = []  # Use a list to store MSE values
    
    for _ in range(num_iterations):
        predictions = X.dot(theta)
        errors_current = predictions - y
        gradient = X.T.dot(errors_current) / m
        theta -= learning_rate * gradient
        mse = (errors_current ** 2).mean()
        errors.append(mse)
    
    return theta, errors

# %%
df_encoded = pd.get_dummies(df, columns=['month', 'day'], drop_first=True)
X = df_encoded.drop('area', axis=1)
y = df_encoded['area']

# %%
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)

# %%
learning_rates = [0.001, 0.01, 0.1]
num_iterations_list = [100, 500, 1000]
results = []

# %%
for lr in learning_rates:
    for num_iter in num_iterations_list:
        theta, errors = gradient_descent(X_train, y_train, learning_rate=lr, num_iterations=num_iter)
        final_mse = errors[-1]
        results.append({'learning_rate': lr, 'num_iterations': num_iter, 'mse': final_mse})

# %%
import json

# %%
log_file = 'gradient_descent_log.json'

with open(log_file, 'w') as f:
    json.dump(results, f, indent=4)

# %%
best_result = min(results, key=lambda x: x['mse'])
print(f"Best hyperparameters: {best_result}")
# Out:
# Best hyperparameters: {'learning_rate': 0.1, 'num_iterations': 1000, 'mse': 2096.449509804474}

# %%
best_lr = best_result['learning_rate']
best_num_iter = best_result['num_iterations']
theta_best, _ = gradient_descent(X_train, y_train, learning_rate=best_lr, num_iterations=best_num_iter)

# %%
predictions = X_test.dot(theta_best)
mse_test = ((predictions - y_test) ** 2).mean()
print(f"Test MSE: {mse_test}")
# Out:
# Test MSE: 11953.662845602592
